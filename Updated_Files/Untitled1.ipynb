# %%
import pandas as pd

# %%
geographies = {"State": [], "Region": []}

# %%
# South = ["AR","LA","MS","TN","AL","KY","WV","VA","GA","FL","SC","NC"]
# SouthWest = ["NV","AZ","NM","TX"]
# West_Coast = ["CA","OR","WA"]
# Mountain = ["ID","UT","CO","WY","MT"]
# Plains = ["ND","SD","NE","KS","OK"]
# MidWest = ["MN","IA","MO","WI","MI","IL","OH","IN"]
# NorthEast = ["PA","NY","MD","DE","NJ","DC","CT","RI","MA","VT","ME","NH"]

geographies_1 = {"South":["AR","LA","MS","TN","AL","KY","WV","VA","GA","FL","SC","NC"],
                 "SouthWest":["NV","AZ","NM","TX"], 
                 "West_Coast":["CA","OR","WA","HI","AK"],
                 "Mountain": ["ID","UT","CO","WY","MT"],
                 "Plains": ["ND","SD","NE","KS","OK"],
                 "MidWest": ["MN","IA","MO","WI","MI","IL","OH","IN"],
                 "NorthEast": ["PA","NY","MD","DE","NJ","DC","CT","RI","MA","VT","ME","NH"]}

# %%
Regions = ["South","SouthWest","West_Coast","Mountain","Plains","MidWest","NorthEast"]

# %%
for key in geographies_1:
#     print(key)
#     print(geographies_1[key])
    for state in geographies_1[key]:
        geographies["State"].append(state)
        print(state)
        geographies["Region"].append(key)
        print(key)
# Out:
# AR
# South
# LA
# South
# MS
# South
# TN
# South
# AL
# South
# KY
# South
# WV
# South
# VA
# South
# GA
# South
# FL
# South
# SC
# South
# NC
# South
# NV
# SouthWest
# AZ
# SouthWest
# NM
# SouthWest
# TX
# SouthWest
# CA
# West_Coast
# OR
# West_Coast
# WA
# West_Coast
# HI
# West_Coast
# AK
# West_Coast
# ID
# Mountain
# UT
# Mountain
# CO
# Mountain
# WY
# Mountain
# MT
# Mountain
# ND
# Plains
# SD
# Plains
# NE
# Plains
# KS
# Plains
# OK
# Plains
# MN
# MidWest
# IA
# MidWest
# MO
# MidWest
# WI
# MidWest
# MI
# MidWest
# IL
# MidWest
# OH
# MidWest
# IN
# MidWest
# PA
# NorthEast
# NY
# NorthEast
# MD
# NorthEast
# DE
# NorthEast
# NJ
# NorthEast
# DC
# NorthEast
# CT
# NorthEast
# RI
# NorthEast
# MA
# NorthEast
# VT
# NorthEast
# ME
# NorthEast
# NH
# NorthEast

# %%
geographies
# Out:
# {'State': ['AR',
#   'LA',
#   'MS',
#   'TN',
#   'AL',
#   'KY',
#   'WV',
#   'VA',
#   'GA',
#   'FL',
#   'SC',
#   'NC',
#   'NV',
#   'AZ',
#   'NM',
#   'TX',
#   'CA',
#   'OR',
#   'WA',
#   'ID',
#   'UT',
#   'CO',
#   'WY',
#   'MT',
#   'ND',
#   'SD',
#   'NE',
#   'KS',
#   'OK',
#   'MN',
#   'IA',
#   'MO',
#   'WI',
#   'MI',
#   'IL',
#   'OH',
#   'IN',
#   'PA',
#   'NY',
#   'MD',
#   'DE',
#   'NJ',
#   'DC',
#   'CT',
#   'RI',
#   'MA',
#   'VT',
#   'ME',
#   'NH'],
#  'Region': ['South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'South',
#   'SouthWest',
#   'SouthWest',
#   'SouthWest',
#   'SouthWest',
#   'West_Coast',
#   'West_Coast',
#   'West_Coast',
#   'Mountain',
#   'Mountain',
#   'Mountain',
#   'Mountain',
#   'Mountain',
#   'Plains',
#   'Plains',
#   'Plains',
#   'Plains',
#   'Plains',
#   'MidWest',
#   'MidWest',
#   'MidWest',
#   'MidWest',
# ...

# %%
us_state_abbrev = {
    'United States': 'USA',
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York City':"NYC",
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico':'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}
