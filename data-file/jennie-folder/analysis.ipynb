# %%
import json
import requests
import numpy as np
import pandas as pd
from sodapy import Socrata
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
ethnicity_df = pd.read_csv("../jennie-folder/demographic_ethnicity.csv")
ethnicity_df.head()
# Out:
#   State  White Fatality Rate (%)  White Population %  Black Fatality Rate (%)  \
# 0    AL                 0.129091           66.561433                 0.092776
# 1    AK                 0.023137           64.128095                 0.000000
# 2    AZ                 0.095577           62.720366                 0.062148
# 3    AR                 0.070212           73.893365                 0.046715
# 4    CA                 0.132411           48.239420                 0.116991
#
#    Black/African American Population %  AIAN Fatality Rate (%)  \
# 0                            26.404481                0.000000
# 1                             3.078420                0.030521
# 2                             3.781046                0.110077
# 3                            14.921160                0.122414
# 4                             4.687652                0.122980
#
#    AIAN Population %  Asian Fatality Rate (%)  Asian Population %  \
# ...

# %%
sex_df = pd.read_csv("../jennie-folder/demographic_sex.csv")
sex_df.head()
# Out:
#   State  Male Population (%)  Crude Male Mortality Rate (%)  \
# 0    AL            48.327995                       0.240166
# 1    AK            52.004046                       0.051783
# 2    AZ            49.746885                       0.255486
# 3    AR            48.866825                       0.209805
# 4    CA            49.708149                       0.192665
#
#    Female Population (%)  Crude Female Mortality Rate (%)
# 0              51.672005                         0.195139
# 1              47.995954                         0.039589
# 2              50.253115                         0.176418
# 3              51.133175                         0.185536
# 4              50.291851                         0.131933

# %%
age_df = pd.read_csv("../jennie-folder/demographic_age.csv")
age_df.head()
# Out:
#   State  65 Years and Over Population  65 Years and Over COVID Deaths  \
# 0    AL                      849837.0                          8260.0
# 1    AK                       91588.0                           262.0
# 2    AZ                     1308633.0                         11765.0
# 3    AR                      523882.0                          4838.0
# 4    CA                     5838115.0                         46820.0
#
#    65 Years and Over Crude Mortality Rate (%)
# 0                                    0.971951
# 1                                    0.286064
# 2                                    0.899030
# 3                                    0.923490
# 4                                    0.801971
